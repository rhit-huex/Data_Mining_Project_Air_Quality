# %% [markdown]
# ## Units of Measure (Pay attention to this)
# ### Two Types of Values Stored:
# * Reported Value - What the monitor actually measured (in various units)
# * Standard Value - Converted to the official standard unit for that parameter
#
# Standard Units by Pollutant Type:
# Criteria Pollutants:
# * Ozone (44201): Parts per million (ppm)
# * CO (42101): Parts per million (ppm)
# * SO₂ (42401): Parts per billion (ppb)
# * NO₂ (42602): Parts per billion (ppb)
#
# Particulate Matter:
# * PM2.5 (88101, 88502): Micrograms/cubic meter at Local Conditions (LC)
# * PM10 (81102, 85101): Micrograms/cubic meter
#
# Metals and Elements:
# Varies by size fraction:
# * TSP (Total Suspended Particulates): Usually micrograms/m³ at 25°C
# * PM2.5: Usually micrograms/m³ at LC
# * PM10: Often nanograms/m³
#
# Important Abbreviations:
# * LC = Local Conditions (temperature/pressure at site)
# * STP = Standard Temperature & Pressure (25°C, 1 atm)
# * Parts per billion Carbon (ppbC) = Used for VOCs

# %%
### IMPORTS ###
import requests
import pandas as pd
import json
import time
from datetime import datetime, date
from typing import Dict, List, Optional

# %%
# GLOBAL ENVIRONMENT VARS:
MY_EMAIL = "huex@rose-hulman.edu"
MY_KEY = "orangecat14"

# %%
# Signing up for the API
def signup_for_api_key(email):
    url = f"https://aqs.epa.gov/data/api/signup"
    params = {'email': email}

    response = requests.get(url, params=params)
    data = response.json()

    return data

# %%
#api_key_data = signup_for_api_key(MY_EMAIL)

# %%
#api_key_data

# %%
# API TEST CALL - Fixed version
url = "https://aqs.epa.gov/data/api/dailyData/byState"

params = {
    'email': MY_EMAIL,
    'key': MY_KEY,
    'param': '44201',      # Ozone
    'bdate': '20230101',
    'edate': '20230131',
    'state': '01'          # Alabama - must be zero-padded!
}

response = requests.get(url, params=params)  # Use GET, not POST
data = response.json()

print(f"Status: {response.status_code}")
print(f"Header: {data.get('Header', [{}])[0].get('status', 'Unknown')}")
# Out:
# Status: 200
# Header: Success

# %%
print(response.url)
# Out:
# https://aqs.epa.gov/data/api/dailyData/byState?email=huex%40rose-hulman.edu&key=orangecat14&param=44201&bdate=20230101&edate=20230131&state=01

# %%
#print(f"{data.get("Data")}")

df = pd.DataFrame(data["Data"])
print(f"Got {len(df)} rows")
print(f"Columns: {list(df.columns)}")

df
# Out:
# Got 248 rows
# Columns: ['state_code', 'county_code', 'site_number', 'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter', 'sample_duration_code', 'sample_duration', 'pollutant_standard', 'date_local', 'units_of_measure', 'event_type', 'observation_count', 'observation_percent', 'validity_indicator', 'arithmetic_mean', 'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method', 'local_site_name', 'site_address', 'state', 'county', 'city', 'cbsa_code', 'cbsa', 'date_of_last_change']
#     state_code county_code site_number parameter_code  poc   latitude  \
# 0           01         073        0023          44201    1  33.553056
# 1           01         073        0023          44201    1  33.553056
# 2           01         073        0023          44201    1  33.553056
# 3           01         073        0023          44201    1  33.553056
# 4           01         073        0023          44201    1  33.553056
# ..         ...         ...         ...            ...  ...        ...
# 243         01         049        9991          44201    1  34.289001
# 244         01         049        9991          44201    1  34.289001
# 245         01         049        9991          44201    1  34.289001
# 246         01         049        9991          44201    1  34.289001
# 247         01         049        9991          44201    1  34.289001
#
#      longitude  datum parameter sample_duration_code  ... method_code  \
# 0   -86.815000  WGS84     Ozone                    1  ...         087
# 1   -86.815000  WGS84     Ozone                    W  ...         087
# 2   -86.815000  WGS84     Ozone                    1  ...         087
# 3   -86.815000  WGS84     Ozone                    W  ...         087
# 4   -86.815000  WGS84     Ozone                    1  ...         087
# ..         ...    ...       ...                  ...  ...         ...
# 243 -85.970065  NAD83     Ozone                    W  ...         047
# 244 -85.970065  NAD83     Ozone                    1  ...         047
# 245 -85.970065  NAD83     Ozone                    W  ...         047
# 246 -85.970065  NAD83     Ozone                    W  ...         047
# 247 -85.970065  NAD83     Ozone                    W  ...         047
#
#                                      method   local_site_name  \
# 0    INSTRUMENTAL - ULTRA VIOLET ABSORPTION  North Birmingham
# 1    INSTRUMENTAL - ULTRA VIOLET ABSORPTION  North Birmingham
# 2    INSTRUMENTAL - ULTRA VIOLET ABSORPTION  North Birmingham
# 3    INSTRUMENTAL - ULTRA VIOLET ABSORPTION  North Birmingham
# 4    INSTRUMENTAL - ULTRA VIOLET ABSORPTION  North Birmingham
# ..                                      ...               ...
# 243             INSTRUMENTAL - ULTRA VIOLET     Sand Mountain
# 244             INSTRUMENTAL - ULTRA VIOLET     Sand Mountain
# 245             INSTRUMENTAL - ULTRA VIOLET     Sand Mountain
# 246             INSTRUMENTAL - ULTRA VIOLET     Sand Mountain
# 247             INSTRUMENTAL - ULTRA VIOLET     Sand Mountain
#
#                                           site_address    state     county  \
# 0                NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama  Jefferson
# 1                NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama  Jefferson
# 2                NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama  Jefferson
# 3                NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama  Jefferson
# 4                NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama  Jefferson
# ..                                                 ...      ...        ...
# 243  Sand Mountain Alabama Agricultural Experiment ...  Alabama     DeKalb
# 244  Sand Mountain Alabama Agricultural Experiment ...  Alabama     DeKalb
# 245  Sand Mountain Alabama Agricultural Experiment ...  Alabama     DeKalb
# 246  Sand Mountain Alabama Agricultural Experiment ...  Alabama     DeKalb
# 247  Sand Mountain Alabama Agricultural Experiment ...  Alabama     DeKalb
#
#            city cbsa_code                   cbsa  date_of_last_change
# 0    Birmingham     13820  Birmingham-Hoover, AL           2024-05-24
# 1    Birmingham     13820  Birmingham-Hoover, AL           2024-05-24
# 2    Birmingham     13820  Birmingham-Hoover, AL           2024-05-24
# 3    Birmingham     13820  Birmingham-Hoover, AL           2024-05-24
# 4    Birmingham     13820  Birmingham-Hoover, AL           2024-05-24
# ..          ...       ...                    ...                  ...
# 243  Crossville     22840         Fort Payne, AL           2024-05-24
# 244  Crossville     22840         Fort Payne, AL           2024-05-24
# 245  Crossville     22840         Fort Payne, AL           2024-05-24
# 246  Crossville     22840         Fort Payne, AL           2024-05-24
# 247  Crossville     22840         Fort Payne, AL           2024-05-24
#
# [248 rows x 32 columns]

# %%
# Date of last change is the last time the data was changed not the day of collection

# %%
def fmt_yyyymmdd(d):
    # Accepts str, date/datetime, or pandas Timestamp and returns 'YYYYMMDD'
    return pd.to_datetime(d).strftime('%Y%m%d')

# %%
fmt_yyyymmdd(date(2020, 5, 17))
# Out:
# '20200517'

# %%
def fmt_scode(sc):
    return f"{sc:02d}"

# %%
fmt_scode(1)
# Out:
# '01'

# %%
ALL_PARAMS = {
    "Carbon Monoxide": {
        "parameter_code": 42101,
        "abbreviation": "CO",
        "description": "Carbon monoxide concentration (ppm)"
    },
    "Nitrogen Dioxide": {
        "parameter_code": 42602,
        "abbreviation": "NO2",
        "description": "Nitrogen dioxide concentration (ppb)"
    },
    "Ozone": {
        "parameter_code": 44201,
        "abbreviation": "O3",
        "description": "Ozone concentration (ppm)"
    },
    "Sulfur Dioxide": {
        "parameter_code": 42401,
        "abbreviation": "SO2",
        "description": "Sulfur dioxide concentration (ppb)"
    },
    "PM10 (Coarse Particulate Matter)": {
        "parameter_code": 81102,
        "abbreviation": "PM10",
        "description": "Particulate matter with diameter ≤ 10 μm (µg/m³)"
    },
    "PM2.5 (Fine Particulate Matter)": {
        "parameter_code": 88101,
        "abbreviation": "PM2.5",
        "description": "Particulate matter with diameter ≤ 2.5 μm (µg/m³)"
    },
    "Lead": {
        "parameter_code": 14129,
        "abbreviation": "Pb (TSP) LC",
        "description": "Lead measured as total suspended particulates (µg/m³)"
    }
}

# %%
def get_daily_data_per_year(start_year, params):
    url = "https://aqs.epa.gov/data/api/dailyData/byState"
    all_data = []

    # get the end_date (one year from start)
    start_date = date(start_year, 1, 1)
    end_date   = date(start_year, 12, 31)

    # Convert dates to a single string
    start_date = fmt_yyyymmdd(start_date)
    end_date   = fmt_yyyymmdd(end_date)

    # Get all the parameter codes
    param_codes = [params["parameter_code"] for params in ALL_PARAMS.values()]

    for param_code in param_codes:
        for state in range(0, 56):
            time.sleep(5) # Wait 5 per api limitations
            state_code = fmt_scode(state)

            params = {
                'email': MY_EMAIL,
                'key': MY_KEY,
                'param': param_code,
                'bdate': start_date,
                'edate': end_date,
                'state': state_code
            }

            response = requests.get(url, params=params)  # Use GET, not POST
            data = response.json()
            if data:
                all_data.extend(data["Data"])
    return pd.DataFrame(all_data)

# %%
test_df = get_daily_data_per_year(2020, ALL_PARAMS)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~\.pyenv\pyenv-win\versions\3.12.4\Lib\http\client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 test_df = get_daily_data_per_year(2020, ALL_PARAMS)
#
# Cell In[37], line 30, in get_daily_data_per_year(start_year, params)
#      19 state_code = fmt_scode(state)
#      21 params = {
#      22     'email': MY_EMAIL,
#      23     'key': MY_KEY,
#    (...)     27     'state': state_code
#      28 }
# ---> 30 response = requests.get(url, params=params)  # Use GET, not POST
#      31 data = response.json()
#      32 if data:
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\huex\Documents\MA384(DataMining)\venv\Lib\site-packages\requests\adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#    (...)    655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#     662     if isinstance(e.reason, ConnectTimeoutError):
#     663         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
test_df
# Out:
#       state_code county_code site_number parameter_code  poc   latitude  \
# 0             01         073        0023          42101    2  33.553056
# 1             01         073        0023          42101    2  33.553056
# 2             01         073        0023          42101    2  33.553056
# 3             01         073        0023          42101    2  33.553056
# 4             01         073        0023          42101    2  33.553056
# ...          ...         ...         ...            ...  ...        ...
# 57042         01         109        0003          14129    2  31.790479
# 57043         01         109        0003          14129    2  31.790479
# 57044         01         109        0003          14129    2  31.790479
# 57045         01         109        0003          14129    2  31.790479
# 57046         01         109        0003          14129    2  31.790479
#
#        longitude  datum        parameter sample_duration_code  ...  \
# 0     -86.815000  WGS84  Carbon monoxide                    1  ...
# 1     -86.815000  WGS84  Carbon monoxide                    Z  ...
# 2     -86.815000  WGS84  Carbon monoxide                    1  ...
# 3     -86.815000  WGS84  Carbon monoxide                    Z  ...
# 4     -86.815000  WGS84  Carbon monoxide                    1  ...
# ...          ...    ...              ...                  ...  ...
# 57042 -85.978974  NAD83    Lead (TSP) LC                    7  ...
# 57043 -85.978974  NAD83    Lead (TSP) LC                    7  ...
# 57044 -85.978974  NAD83    Lead (TSP) LC                    7  ...
# 57045 -85.978974  NAD83    Lead (TSP) LC                    7  ...
# 57046 -85.978974  NAD83    Lead (TSP) LC                    7  ...
#
#       method_code                                             method  \
# 0             093  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# 1             093  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# 2             093  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# 3             093  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# 4             093  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER
# ...           ...                                                ...
# 57042         813  HI-VOL - ICP-MS  FRM; Heated ultrasonic 1.03M ...
# 57043         813  HI-VOL - ICP-MS  FRM; Heated ultrasonic 1.03M ...
# 57044         813  HI-VOL - ICP-MS  FRM; Heated ultrasonic 1.03M ...
# 57045         813  HI-VOL - ICP-MS  FRM; Heated ultrasonic 1.03M ...
# 57046         813  HI-VOL - ICP-MS  FRM; Heated ultrasonic 1.03M ...
#
#         local_site_name                           site_address    state  \
# 0      North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama
# 1      North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama
# 2      North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama
# 3      North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama
# 4      North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.  Alabama
# ...                 ...                                    ...      ...
# 57042         TROY LEAD                         HENDERSON ROAD  Alabama
# 57043         TROY LEAD                         HENDERSON ROAD  Alabama
# 57044         TROY LEAD                         HENDERSON ROAD  Alabama
# 57045         TROY LEAD                         HENDERSON ROAD  Alabama
# 57046         TROY LEAD                         HENDERSON ROAD  Alabama
#
#           county        city cbsa_code                   cbsa  \
# 0      Jefferson  Birmingham     13820  Birmingham-Hoover, AL
# 1      Jefferson  Birmingham     13820  Birmingham-Hoover, AL
# 2      Jefferson  Birmingham     13820  Birmingham-Hoover, AL
# 3      Jefferson  Birmingham     13820  Birmingham-Hoover, AL
# 4      Jefferson  Birmingham     13820  Birmingham-Hoover, AL
# ...          ...         ...       ...                    ...
# 57042       Pike        Troy     45980               Troy, AL
# 57043       Pike        Troy     45980               Troy, AL
# 57044       Pike        Troy     45980               Troy, AL
# 57045       Pike        Troy     45980               Troy, AL
# 57046       Pike        Troy     45980               Troy, AL
#
#        date_of_last_change
# 0               2021-10-30
# 1               2023-02-05
# 2               2021-10-30
# 3               2023-02-05
# 4               2021-10-30
# ...                    ...
# 57042           2024-03-20
# 57043           2024-03-20
# 57044           2024-03-20
# 57045           2024-03-20
# 57046           2024-03-20
#
# [57047 rows x 32 columns]
